# %% [markdown]
# <a href="https://colab.research.google.com/github/tettehdaniel/my-vis-5609/blob/main/Notebooks/Notebook03_DataManipulation1_SV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 03 — Data Manipulation One

# %% [markdown]
# **Main Objective**
#
# 1. Sorting
# 2. Selecting
# 3. Filtering

# %% [markdown]
# ## Setup
#
# Please run the setup code below

# %%
! wget -q -nc https://raw.githubusercontent.com/taylor-arnold/fds-py/refs/heads/main/funs.py

from funs import *

# %%
import numpy as np
import polars as pl

from plotnine import *
from polars import col as c
theme_set(theme_minimal())

path = "https://raw.githubusercontent.com/ajcollins16/DSST289_Fall2026_AJC/refs/heads/main/"

# %%
dat = pl.read_csv(path + "Data/food.csv").drop(c.description)

# %%
dat.head()
# Out:
# shape: (5, 16)
# ┌───────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬────────┐
# │ item      ┆ food_group ┆ calories ┆ total_fat ┆ … ┆ vitamin_a ┆ vitamin_c ┆ wiki      ┆ color  │
# │ ---       ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---    │
# │ str       ┆ str        ┆ i64      ┆ f64       ┆   ┆ i64       ┆ i64       ┆ str       ┆ str    │
# ╞═══════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪════════╡
# │ Apple     ┆ fruit      ┆ 52       ┆ 0.1       ┆ … ┆ 1         ┆ 8         ┆ apple     ┆ red    │
# │ Asparagus ┆ vegetable  ┆ 20       ┆ 0.1       ┆ … ┆ 15        ┆ 9         ┆ asparagus ┆ green  │
# │ Avocado   ┆ fruit      ┆ 160      ┆ 14.6      ┆ … ┆ 3         ┆ 17        ┆ avocado   ┆ green  │
# │ Banana    ┆ fruit      ┆ 89       ┆ 0.3       ┆ … ┆ 1         ┆ 15        ┆ banana    ┆ yellow │
# ...

# %% [markdown]
# ## Sorting, Selecting, and Filtering
#
# Although simple in concept, the ability to sort, select, and filter data is one of the first steps to cleaning messy data. Simply put:
# - Sorting &rarr; reordering data to inspect certain things.
# - Selecting &rarr; picking the variables that are most important for what you want to accomplish.
# - Filtering &rarr; removing observations based on a set of condition(s).
#
# We are going to work through a number of data manipulation exercises today. Although simple, starting small is the best path forward for more complex data manipulations. The data we will be working with continues to be the food dataset we have been working with.

# %% [markdown]
# ### Questions
#
# 1. Start by sorting the food data by calories, with the lowest caloric foods at the top (display only).

# %%
(
    dat
    .sort(c.calories)
)
# Out:
# shape: (61, 16)
# ┌───────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬────────┐
# │ item      ┆ food_group ┆ calories ┆ total_fat ┆ … ┆ vitamin_a ┆ vitamin_c ┆ wiki      ┆ color  │
# │ ---       ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---    │
# │ str       ┆ str        ┆ i64      ┆ f64       ┆   ┆ i64       ┆ i64       ┆ str       ┆ str    │
# ╞═══════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪════════╡
# │ Cucumber  ┆ vegetable  ┆ 12       ┆ 0.1       ┆ … ┆ 1         ┆ 5         ┆ cucumber  ┆ green  │
# │ Celery    ┆ vegetable  ┆ 14       ┆ 0.1       ┆ … ┆ 9         ┆ 5         ┆ celery    ┆ green  │
# │ Lettuce   ┆ vegetable  ┆ 14       ┆ 0.1       ┆ … ┆ 10        ┆ 5         ┆ lettuce   ┆ green  │
# │ Tomato    ┆ vegetable  ┆ 18       ┆ 0.0       ┆ … ┆ 17        ┆ 21        ┆ tomato    ┆ red    │
# ...

# %% [markdown]
# 2. Next, sort the data by calories from highest to lowest (display only).

# %%
(
    dat
    .sort(c.calories, descending=True) #argument
)
# Out:
# shape: (61, 16)
# ┌───────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬────────┐
# │ item      ┆ food_group ┆ calories ┆ total_fat ┆ … ┆ vitamin_a ┆ vitamin_c ┆ wiki      ┆ color  │
# │ ---       ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---    │
# │ str       ┆ str        ┆ i64      ┆ f64       ┆   ┆ i64       ┆ i64       ┆ str       ┆ str    │
# ╞═══════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪════════╡
# │ Oat       ┆ grains     ┆ 389      ┆ 6.0       ┆ … ┆ 0         ┆ 0         ┆ oat       ┆ brown  │
# │ Cheese    ┆ dairy      ┆ 350      ┆ 26.9      ┆ … ┆ 16        ┆ 0         ┆ cheese    ┆ yellow │
# │ Lamb      ┆ meat       ┆ 292      ┆ 20.7      ┆ … ┆ 0         ┆ 0         ┆ sheep     ┆ red    │
# │ Beef      ┆ meat       ┆ 288      ┆ 19.5      ┆ … ┆ 0         ┆ 0         ┆ beef      ┆ red    │
# ...

# %% [markdown]
# 3. Now, sort the data based on the food groups (alphabetical order) and then within each food group by calories (display only). *Note: from now on if it says "sort" I am implying ascending order unless otherwise noted.*

# %%
(
    dat
    .sort(c.food_group, c.calories)
)
# Out:
# shape: (61, 16)
# ┌────────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬────────────┬────────┐
# │ item       ┆ food_group ┆ calories ┆ total_fat ┆ … ┆ vitamin_a ┆ vitamin_c ┆ wiki       ┆ color  │
# │ ---        ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---        ┆ ---    │
# │ str        ┆ str        ┆ i64      ┆ f64       ┆   ┆ i64       ┆ i64       ┆ str        ┆ str    │
# ╞════════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪════════════╪════════╡
# │ Milk       ┆ dairy      ┆ 60       ┆ 3.2       ┆ … ┆ 2         ┆ 0         ┆ milk       ┆ white  │
# │ Yogurt     ┆ dairy      ┆ 99       ┆ 1.1       ┆ … ┆ 1         ┆ 1         ┆ yogurt     ┆ white  │
# │ Sour Cream ┆ dairy      ┆ 214      ┆ 20.9      ┆ … ┆ 13        ┆ 2         ┆ sour_cream ┆ white  │
# │ Cheese     ┆ dairy      ┆ 350      ┆ 26.9      ┆ … ┆ 16        ┆ 0         ┆ cheese     ┆ yellow │
# ...

# %% [markdown]
# 4. Now, select only the food groups and calories columns of the dataset (display only).

# %%
(
    dat
    .select(c.food_group, c.calories)
)
# Out:
# shape: (61, 2)
# ┌────────────┬──────────┐
# │ food_group ┆ calories │
# │ ---        ┆ ---      │
# │ str        ┆ i64      │
# ╞════════════╪══════════╡
# │ fruit      ┆ 52       │
# │ vegetable  ┆ 20       │
# │ fruit      ┆ 160      │
# │ fruit      ┆ 89       │
# │ grains     ┆ 180      │
# │ …          ┆ …        │
# │ vegetable  ┆ 18       │
# │ fish       ┆ 153      │
# │ meat       ┆ 187      │
# │ vegetable  ┆ 104      │
# │ dairy      ┆ 99       │
# └────────────┴──────────┘

# %% [markdown]
# 5. Let's chain several things together. Create a new dataset variable (call it `dat2`) that has the ten items with the largest amount of calories per serving. Make sure you inspect the new dataset to make sure you did the correct manipulation.

# %%
dat2 = (
    dat
    .sort(c.calories, descending=True)
    .head(10)
)
dat2
# Out:
# shape: (10, 16)
# ┌────────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬────────────┬────────┐
# │ item       ┆ food_group ┆ calories ┆ total_fat ┆ … ┆ vitamin_a ┆ vitamin_c ┆ wiki       ┆ color  │
# │ ---        ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---        ┆ ---    │
# │ str        ┆ str        ┆ i64      ┆ f64       ┆   ┆ i64       ┆ i64       ┆ str        ┆ str    │
# ╞════════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪════════════╪════════╡
# │ Oat        ┆ grains     ┆ 389      ┆ 6.0       ┆ … ┆ 0         ┆ 0         ┆ oat        ┆ brown  │
# │ Cheese     ┆ dairy      ┆ 350      ┆ 26.9      ┆ … ┆ 16        ┆ 0         ┆ cheese     ┆ yellow │
# │ Lamb       ┆ meat       ┆ 292      ┆ 20.7      ┆ … ┆ 0         ┆ 0         ┆ sheep      ┆ red    │
# │ Beef       ┆ meat       ┆ 288      ┆ 19.5      ┆ … ┆ 0         ┆ 0         ┆ beef       ┆ red    │
# ...

# %% [markdown]
# 6. With the new dataset, extract the one row with the lowest amount of protein from those 10 highest caloric items.

# %%
(
    dat2
    .sort(c.protein)
    .head(1)
)
# Out:
# shape: (1, 16)
# ┌────────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬────────────┬───────┐
# │ item       ┆ food_group ┆ calories ┆ total_fat ┆ … ┆ vitamin_a ┆ vitamin_c ┆ wiki       ┆ color │
# │ ---        ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---        ┆ ---   │
# │ str        ┆ str        ┆ i64      ┆ f64       ┆   ┆ i64       ┆ i64       ┆ str        ┆ str   │
# ╞════════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪════════════╪═══════╡
# │ Sour Cream ┆ dairy      ┆ 214      ┆ 20.9      ┆ … ┆ 13        ┆ 2         ┆ sour_cream ┆ white │
# └────────────┴────────────┴──────────┴───────────┴───┴───────────┴───────────┴────────────┴───────┘

# %% [markdown]
# 7. Going back to the original dataset, filter just those rows where the amount of iron is more than 1mg (display **only**).

# %%
(
    dat
    .filter(c.iron > 1)
)
# Out:
# shape: (46, 16)
# ┌─────────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬────────────┬───────┐
# │ item        ┆ food_group ┆ calories ┆ total_fat ┆ … ┆ vitamin_a ┆ vitamin_c ┆ wiki       ┆ color │
# │ ---         ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---        ┆ ---   │
# │ str         ┆ str        ┆ i64      ┆ f64       ┆   ┆ i64       ┆ i64       ┆ str        ┆ str   │
# ╞═════════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪════════════╪═══════╡
# │ Asparagus   ┆ vegetable  ┆ 20       ┆ 0.1       ┆ … ┆ 15        ┆ 9         ┆ asparagus  ┆ green │
# │ Avocado     ┆ fruit      ┆ 160      ┆ 14.6      ┆ … ┆ 3         ┆ 17        ┆ avocado    ┆ green │
# │ Chickpea    ┆ grains     ┆ 180      ┆ 2.9       ┆ … ┆ 0         ┆ 3         ┆ chickpea   ┆ brown │
# │ String Bean ┆ vegetable  ┆ 31       ┆ 0.1       ┆ … ┆ 14        ┆ 27        ┆ green_bean ┆ green │
# ...

# %% [markdown]
# 8. Instead, now filter those rows where the amount of iron is more than or equal to 1mg (display only).

# %%
(
    dat
    .filter(c.iron >= 1)
)
# Out:
# shape: (58, 16)
# ┌───────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬─────────────┬────────┐
# │ item      ┆ food_group ┆ calories ┆ total_fat ┆ … ┆ vitamin_a ┆ vitamin_c ┆ wiki        ┆ color  │
# │ ---       ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---         ┆ ---    │
# │ str       ┆ str        ┆ i64      ┆ f64       ┆   ┆ i64       ┆ i64       ┆ str         ┆ str    │
# ╞═══════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═════════════╪════════╡
# │ Apple     ┆ fruit      ┆ 52       ┆ 0.1       ┆ … ┆ 1         ┆ 8         ┆ apple       ┆ red    │
# │ Asparagus ┆ vegetable  ┆ 20       ┆ 0.1       ┆ … ┆ 15        ┆ 9         ┆ asparagus   ┆ green  │
# │ Avocado   ┆ fruit      ┆ 160      ┆ 14.6      ┆ … ┆ 3         ┆ 17        ┆ avocado     ┆ green  │
# │ Banana    ┆ fruit      ┆ 89       ┆ 0.3       ┆ … ┆ 1         ┆ 15        ┆ banana      ┆ yellow │
# ...

# %% [markdown]
# 9. Filter those rows where the food group is "fruit" and the iron is greater than 1. Make sure to use two different calls to the `.filter` function (display only).

# %%
(
    dat
    .filter((c.food_group == "fruit") & (c.iron > 1))
)
# Out:
# shape: (7, 16)
# ┌────────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬────────────┬────────┐
# │ item       ┆ food_group ┆ calories ┆ total_fat ┆ … ┆ vitamin_a ┆ vitamin_c ┆ wiki       ┆ color  │
# │ ---        ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---        ┆ ---    │
# │ str        ┆ str        ┆ i64      ┆ f64       ┆   ┆ i64       ┆ i64       ┆ str        ┆ str    │
# ╞════════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪════════════╪════════╡
# │ Avocado    ┆ fruit      ┆ 160      ┆ 14.6      ┆ … ┆ 3         ┆ 17        ┆ avocado    ┆ green  │
# │ Grape      ┆ fruit      ┆ 69       ┆ 0.1       ┆ … ┆ 1         ┆ 18        ┆ grape      ┆ purple │
# │ Kiwi       ┆ fruit      ┆ 61       ┆ 0.5       ┆ … ┆ 2         ┆ 155       ┆ kiwifruit  ┆ green  │
# │ Lemon      ┆ fruit      ┆ 29       ┆ 0.0       ┆ … ┆ 0         ┆ 88        ┆ lemon      ┆ yellow │
# ...

# %% [markdown]
# 10. Now repeat Q9 but this time use only one `.filter` function call making sure to use the correct operator (`|`, the or operator, or `&` the and operator; display only).

# %%
(
    dat
    .filter((c.food_group == "fruit") & (c.iron > 1))
)
# Out:
# shape: (7, 16)
# ┌────────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬────────────┬────────┐
# │ item       ┆ food_group ┆ calories ┆ total_fat ┆ … ┆ vitamin_a ┆ vitamin_c ┆ wiki       ┆ color  │
# │ ---        ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---        ┆ ---    │
# │ str        ┆ str        ┆ i64      ┆ f64       ┆   ┆ i64       ┆ i64       ┆ str        ┆ str    │
# ╞════════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪════════════╪════════╡
# │ Avocado    ┆ fruit      ┆ 160      ┆ 14.6      ┆ … ┆ 3         ┆ 17        ┆ avocado    ┆ green  │
# │ Grape      ┆ fruit      ┆ 69       ┆ 0.1       ┆ … ┆ 1         ┆ 18        ┆ grape      ┆ purple │
# │ Kiwi       ┆ fruit      ┆ 61       ┆ 0.5       ┆ … ┆ 2         ┆ 155       ┆ kiwifruit  ┆ green  │
# │ Lemon      ┆ fruit      ┆ 29       ┆ 0.0       ┆ … ┆ 0         ┆ 88        ┆ lemon      ┆ yellow │
# ...

# %% [markdown]
# 11. Continuing to repeat Q9, this time filter the rows where the food group is either "fruit" or "vegetable" again making sure to use the correct operator.

# %%
(
    dat
    .filter((c.food_group == "fruit") | (c.food_group == "vegetable"))
)
# Out:
# shape: (32, 16)
# ┌────────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬────────────┬────────┐
# │ item       ┆ food_group ┆ calories ┆ total_fat ┆ … ┆ vitamin_a ┆ vitamin_c ┆ wiki       ┆ color  │
# │ ---        ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---        ┆ ---    │
# │ str        ┆ str        ┆ i64      ┆ f64       ┆   ┆ i64       ┆ i64       ┆ str        ┆ str    │
# ╞════════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪════════════╪════════╡
# │ Apple      ┆ fruit      ┆ 52       ┆ 0.1       ┆ … ┆ 1         ┆ 8         ┆ apple      ┆ red    │
# │ Asparagus  ┆ vegetable  ┆ 20       ┆ 0.1       ┆ … ┆ 15        ┆ 9         ┆ asparagus  ┆ green  │
# │ Avocado    ┆ fruit      ┆ 160      ┆ 14.6      ┆ … ┆ 3         ┆ 17        ┆ avocado    ┆ green  │
# │ Banana     ┆ fruit      ┆ 89       ┆ 0.3       ┆ … ┆ 1         ┆ 15        ┆ banana     ┆ yellow │
# ...

# %% [markdown]
# 12. Can you provide the "definition" for what the `&` and `|` operators do fundamentally within Python (or coding in general)?
#
# **Answer (Q12): **& is an "and" operator, while | is an "or" operator**

# %% [markdown]
# 13. Finally, filter the rows that are fruits or vegetables using a different method; the `.is_in` function.

# %%
(
    dat
    .filter(c.food_group.is_in(["fruit", "vegetable"]))
)
# Out:
# shape: (32, 16)
# ┌────────────┬────────────┬──────────┬───────────┬───┬───────────┬───────────┬────────────┬────────┐
# │ item       ┆ food_group ┆ calories ┆ total_fat ┆ … ┆ vitamin_a ┆ vitamin_c ┆ wiki       ┆ color  │
# │ ---        ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---        ┆ ---    │
# │ str        ┆ str        ┆ i64      ┆ f64       ┆   ┆ i64       ┆ i64       ┆ str        ┆ str    │
# ╞════════════╪════════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪════════════╪════════╡
# │ Apple      ┆ fruit      ┆ 52       ┆ 0.1       ┆ … ┆ 1         ┆ 8         ┆ apple      ┆ red    │
# │ Asparagus  ┆ vegetable  ┆ 20       ┆ 0.1       ┆ … ┆ 15        ┆ 9         ┆ asparagus  ┆ green  │
# │ Avocado    ┆ fruit      ┆ 160      ┆ 14.6      ┆ … ┆ 3         ┆ 17        ┆ avocado    ┆ green  │
# │ Banana     ┆ fruit      ┆ 89       ┆ 0.3       ┆ … ┆ 1         ┆ 15        ┆ banana     ┆ yellow │
# ...

# %% [markdown]
# 13. Why do you think this is useful to use the `.is_in`?
#
# **Answer (Q13):**

# %%
#Sometimes we want to know whether a value belongs to a larger set.
